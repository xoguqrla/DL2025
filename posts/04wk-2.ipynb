# %% [markdown]
# <a href="https://colab.research.google.com/github/xoguqrla/DL2025/blob/main/posts/04wk-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# title: "04wk-2: (신경망) -- 꺽인그래프의 한계(?), 시벤코정리, MNIST"
# author: "최규빈"
# date: "03/31/2025"
# draft: false
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DL2025/blob/main/posts/04wk-2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 1. 강의영상

# %%
#{{<video https://youtu.be/playlist?list=PLQqh36zP38-wD7Am2wZ7NNZjHpt55gwEH&si=Yj3LYi8Y9uU5SYtp >}}

# %% [markdown]
# # 2. Imports

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 3. 꺽인그래프의 한계?

# %% [markdown]
# `-` 걱정: 지난시간에 배운 기술은 sig를 취하기 전이 꺽은선인 형태만 가능할 듯 하다. 그래서 이 역시 표현력이 부족할 듯 하다.
#
# `-` 그런데 생각보다 표현력이 풍부한 편이다. 즉 생각보다 쓸 만하다.

# %% [markdown]
# ## A. Step은 표현 불가능하지 않나?

# %% [markdown]
# `# 예제1` -- 일부러 이상하게 만든 취업합격률 곡선

# %%
torch.manual_seed(43052)
x = torch.linspace(-1,1,2000).reshape(-1,1)
u = 0*x-3
u[x<-0.2] = (15*x+6)[x<-0.2]
u[(-0.2<x)&(x<0.4)] = (0*x-1)[(-0.2<x)&(x<0.4)]
sig = torch.nn.Sigmoid()
v = π = sig(u)
y = torch.bernoulli(v)

# %%
#plt.plot(u,alpha=0.2)
plt.plot(x,y,'.',alpha=0.01,color="C0")
plt.plot(x[0],y[0],'o',color="C0",label=r"observed data (with error): $(x_i,y_i)$")
plt.plot(x,v,'--',label=r"prob (true, unknown): $(x_i,\pi_i)$ or $(x_i,v_i)$",color="C1")
plt.legend()

# %% [markdown]
# ***수업 중 코멘트! : 뚝 떨어지는 부분을 곡선으로 표현하는 것이 목표이다!

# %%
#***수업 중 코멘트! :
#net =  torch.nn.Sequential(
#    torch.nn.Linear(1,512),
#    torch.nn.ReLU(),
#    torch.nn.Linear(512,1),
#    torch.nn.Sigmoid()
#)
#loss_fn = torch.nn.BCELoss()
#optimizr = torch.optim.Adam(net.parameters())

# %% [markdown]
# `-` 저 주황색 구조를 어떻게 표현하지? $\to$ 선이 많이 꺽이면되는거아냐?

# %% [markdown]
# $$\underset{(n,1)}{\bf X} \overset{l_1}{\to} \underset{(n,256)}{\boldsymbol u^{(1)}} \overset{a_1}{\to} \underset{(n,256)}{\boldsymbol v^{(1)}} \overset{l_1}{\to} \underset{(n,1)}{\boldsymbol u^{(2)}} \overset{a_2}{\to} \underset{(n,1)}{\boldsymbol v^{(2)}}=\underset{(n,1)}{\hat{\boldsymbol y}}$$

# %%
#torch.manual_seed(43052)
net = torch.nn.Sequential(
    torch.nn.Linear(1,256),
    torch.nn.ReLU(),
    torch.nn.Linear(256,1),
    #torch.nn.Sigmoid()
)
#loss_fn = torch.nn.BCELoss()
loss_fn = torch.nn.BCEWithLogitsLoss()
optimizr = torch.optim.Adam(net.parameters())
#--#
for epoc in range(5000):
    ## 1
    yhat = net(x)
    ## 2
    loss = loss_fn(yhat,y)
    ## 3
    loss.backward()
    ## 4
    optimizr.step()
    optimizr.zero_grad()

# %%
fig,ax = plt.subplots(1,2)
ax[0].plot(x,u,'--',label=r"$(x_i,u_i)$")
ax[0].plot(x,yhat.data,'--',label=r"$(x_i,\hat{u}_i)$")
ax[0].legend()
ax[0].set_title("before sig")
ax[1].plot(x,y,'.',alpha=0.02,color="blue")
ax[1].plot(x,v,'--', color="C0", label=r"$(x_i,v_i)$ or $(x_i,\pi_i)$")
ax[1].plot(x,sig(yhat.data),'--',color="C1",label=r"$(x_i,\hat{v}_i)$ or $(x_i,\hat{\pi}_i)$")
ax[1].legend()
ax[1].set_title("after sig")
# Out:
# Text(0.5, 1.0, 'after sig')

# %%
## 수업 시간에 따로 적은 내용!

#torch.manual_seed(43052)
net = torch.nn.Sequential(
    torch.nn.Linear(1,512),
    torch.nn.ReLU(),
    torch.nn.Linear(512,1),
    #torch.nn.Sigmoid()
)
#loss_fn = torch.nn.BCELoss()
loss_fn = torch.nn.BCEWithLogitsLoss()
optimizr = torch.optim.Adam(net.parameters())
#--#
for epoc in range(5000):
    ## 1
    yhat = net(x)
    ## 2
    loss = loss_fn(yhat,y)
    ## 3
    loss.backward()
    ## 4
    optimizr.step()
    optimizr.zero_grad()

# %%
## 수업 시간에 따로 적은 내용!

fig,ax = plt.subplots(1,2)
ax[0].plot(x,u,'--',label=r"$(x_i,u_i)$")
ax[0].plot(x,yhat.data,'--',label=r"$(x_i,\hat{u}_i)$")
ax[0].legend()
ax[0].set_title("before sig")
ax[1].plot(x,y,'.',alpha=0.02,color="blue")
ax[1].plot(x,v,'--', color="C0", label=r"$(x_i,v_i)$ or $(x_i,\pi_i)$")
ax[1].plot(x,sig(yhat.data),'--',color="C1",label=r"$(x_i,\hat{v}_i)$ or $(x_i,\hat{\pi}_i)$")
ax[1].legend()
ax[1].set_title("after sig")
# Out:
# Text(0.5, 1.0, 'after sig')

# %% [markdown]
# `#`

# %% [markdown]
# ## B. 곡선은 표현 불가능하지 않나?

# %% [markdown]
# `# 예제2` --  2024년 수능 미적30번 문제에 나온 곡선

# %% [markdown]
# $$y_i = e^{-x_i} \times  |\cos(5x_i)| \times \sin(5x) + \epsilon_i, \quad \epsilon_i \sim N(0,\sigma^2)$$

# %%
torch.manual_seed(43052)
x = torch.linspace(0,2,2000).reshape(-1,1)
eps = torch.randn(2000).reshape(-1,1)*0.05
fx = torch.exp(-1*x)* torch.abs(torch.cos(3*x))*(torch.sin(3*x))
y = fx + eps

# %%
plt.plot(x,y,label=r"observed data (with error): $(x_i,y_i)$", alpha=0.2)
plt.plot(x,fx,'--',color="C0",label=r"underlying (true, unknown): $e^{-x}|\cos(3x)|\sin(3x)$")
plt.legend()

# %% [markdown]
# `-` 맞춰본다..

# %% [markdown]
# -   $\underset{(n,1)}{\bf X} \overset{l_1}{\to} \underset{(n,1024)}{\boldsymbol u^{(1)}} \overset{a_1}{\to} \underset{(n,1024)}{\boldsymbol v^{(1)}} \overset{l_1}{\to} \underset{(n,1)}{\boldsymbol u^{(2)}} \overset{a_2}{\to} \underset{(n,1)}{\boldsymbol v^{(2)}}=\underset{(n,1)}{\hat{\boldsymbol y}}$

# %%
#torch.manual_seed(43052)
net = torch.nn.Sequential(
    torch.nn.Linear(1,1024),              # 꺾이지 않은 1024개의 직선
    torch.nn.ReLU(),                      # 꺾인(렐루된)1024개의 직선
    torch.nn.Linear(1024,1)               #합쳐진 하나의 꺾인 직선
)
loss_fn = torch.nn.MSELoss()
optimizr = torch.optim.Adam(net.parameters())        # --> 왜 아담을 쓰냐? 그냥 쓰는 거다. 제일 좋으니까~
#--#
for epoc in range(5000):
    ## 1
    yhat = net(x)
    ## 2
    loss = loss_fn(yhat,y)
    ## 3
    loss.backward()
    ## 4
    optimizr.step()
    optimizr.zero_grad()

# %%
plt.plot(x,y,label=r"observed data: $(x_i,y_i)$", alpha=0.2)
plt.plot(x,fx,'--',color="C0",label=r"underlying (true, unkown): $e^{-x}|\cos(3x)|\sin(3x)$")
plt.plot(x,yhat.data,'--',color="C1",label=r"underlying (esimated): $(x_i,\hat{y}_i)$")
plt.legend()

# %% [markdown]
# `#`

# %% [markdown]
# # 4. 시벤코정리

# %% [markdown]
# ## A. 시벤코의 정리 소개

# %% [markdown]
# ::: {.callout-note}
# ### Universal Approximation Thm [@cybenko1989approximation, @goodfellow2016deep]
#
# 하나의 은닉층을 가지는 아래와 같은 꼴의 네트워크 $net: {\bf X}_{n \times p} \to {\bf y}_{n\times q}$는
#
# ```Python
# net = torch.nn.Sequential(
#     torch.nn.Linear(p,???),
#     torch.nn.Sigmoid(),
#     torch.nn.Linear(???,q)
# )
# ```
#
# 모든 보렐 가측함수 (Borel measurable function)
#
# $$f: {\bf X}_{n \times p} \to {\bf y}_{n\times q}$$
#
# 를 원하는 정확도로 "근사"시킬 수 있다. 쉽게 말하면 ${\bf X} \to {\bf y}$ 인 어떠한 복잡한 규칙라도 하나의 은닉층을 가진 신경망이 원하는 정확도로 근사시킨다는 의미이다. 예를들면 아래와 같은 문제를 해결할 수 있다.
#
# - ${\bf X}_{n\times 2}$는 토익점수, GPA 이고 ${\bf y}_{n\times 1}$는 취업여부일 경우 ${\bf X} \to {\bf y}$인 규칙을 신경망은 항상 찾을 수 있다.
# - ${\bf X}_{n \times p}$는 주택이미지, 지역정보, 주택면적, 주택에 대한 설명 이고 ${\bf y}_{n\times 1}$는 주택가격일 경우 ${\bf X} \to {\bf y}$인 규칙을 신경망은 항상 찾을 수 있다.
#
# 즉 하나의 은닉층을 가진 신경망의 표현력은 거의 무한대라 볼 수 있다.
# :::

# %% [markdown]
# ## B. 왜 가능한가?

# %% [markdown]
# `-` 데이터

# %%
x = torch.linspace(-10,10,200).reshape(-1,1)   # torch.linspace로 -10부터 10까지 200개의 값을 생성한 후, (200, 1) 형태로 reshape

# %% [markdown]
# `-` 아래와 같은 네트워크를 고려하자. (스펙올라도 취업못하는 예제에서 썼던 네크워크랑 비슷해요)

# %%
l1 = torch.nn.Linear(in_features=1, out_features=2)  # 입력 1차원 → 출력 2차원으로 매핑하는 선형 계층
a1 = torch.nn.Sigmoid()                              # Sigmoid 활성화 함수 (출력을 0~1 사이로 비선형 변환)
l2 = torch.nn.Linear(in_features=2, out_features=1)  # 입력 2차원 → 출력 1차원으로 다시 매핑하는 선형 계층

# %% [markdown]
# `-` 직관1: $l_1$,$l_2$의 가중치를 잘 결합하다보면 우연히 아래와 같이 만들 수 있다.

# %%
l1.weight.data = torch.tensor([[-5.00], [5.00]])   # # l1 계층의 가중치 수동 설정
l1.bias.data   = torch.tensor([+10.00, +10.00])    # # l1 계층의 편향 수동 설정

# %%
l2.weight.data = torch.tensor([[1.00, 1.00]])  # 두 뉴런의 출력을 더한 값으로 출력 계산
l2.bias.data   = torch.tensor([-1.00])         # 출력에서 1을 빼는 역할 (임계값 조정)

# %%
fig, ax = plt.subplots(1, 3, figsize=(9, 3))

# l1(x) 의 두 선형 출력: -5x+10, 5x+10
ax[0].plot(x, l1(x)[:, [0]].data, label=r"$-5x+10$")
ax[0].plot(x, l1(x)[:, [1]].data, label=r"$5x+10$")
ax[0].set_title('$l_1(x)$')  # 첫 번째 레이어의 선형 출력
ax[0].legend()

# sigmoid를 적용한 활성화 결과: v1 = sig(-5x+10), v2 = sig(5x+10)
ax[1].plot(x, a1(l1(x))[:, [0]].data, label=r"$v_1=\sigma(-5x+10)$")
ax[1].plot(x, a1(l1(x))[:, [1]].data, label=r"$v_2=\sigma(5x+10)$")
ax[1].set_title('$(a_1 \circ l_1)(x)$')  # 활성화 결과
ax[1].legend()

# 최종 출력: v1 + v2 - 1
ax[2].plot(x, l2(a1(l1(x))).data, color='C2', label=r"$v_1+v_2-1$")
ax[2].set_title('$(l_2 \circ a_1 \circ l_1)(x)$')  # 전체 모델 출력
ax[2].legend()

# %% [markdown]
# `-` 직관2: 아래들도 가능할듯?

# %%
# 가중치 및 편향 설정
l1.weight.data = torch.tensor([[-5.00], [5.00]])  # 첫 번째 레이어: 두 노드의 가중치
l1.bias.data   = torch.tensor([+0.00, +20.00])    # 첫 번째 레이어: 두 노드의 편향
l2.weight.data = torch.tensor([[1.00, 1.00]])      # 두 번째 레이어: 두 값의 합
l2.bias.data   = torch.tensor([-1.00])             # 두 번째 레이어: 편향

# 시각화 코드
fig, ax = plt.subplots(1, 3, figsize=(9, 3))

# 첫 번째 레이어의 선형 출력 l1(x)
ax[0].plot(x, l1(x).data.numpy(), '--', color='C0')
ax[0].set_title('$l_1(x)$')  # 선형 변환 결과

# 시그모이드 활성화 결과 a1(l1(x))
ax[1].plot(x, a1(l1(x)).data.numpy(), '--', color='C0')
ax[1].set_title('$(a_1 \circ l_1)(x)$')  # 활성화 함수 결과

# 전체 모델 출력: l2(a1(l1(x)))
ax[2].plot(x, l2(a1(l1(x))).data, '--', color='C0')
ax[2].set_title('$(l_2 \circ a_1 \circ l_1)(x)$')  # 최종 출력
ax[2].set_ylim(-0.1, 2.6)  # y축 범위 고정

# 이 설정은 한 노드에선 sig(-5x + 0), 다른 노드에선 sig(5x + 20)이 활성화되어, 대부분의 x에서 하나만 반응하게끔 설계된 구조입니다. 결과적으로 sigmoid가 각각 0 또는 1에 가까운 값을 만들고, 이 둘의 합에서 1을 빼는 형태로 출력됩니다.
# Out:
# (-0.1, 2.6)

# %%
# 레이어 가중치 및 편향 설정
l1.weight.data = torch.tensor([[-5.00], [5.00]])    # 첫 번째 레이어 가중치 (2개의 노드)
l1.bias.data   = torch.tensor([+20.00, +00.00])     # 첫 번째 레이어 편향 (노드마다 다르게 설정)
l2.weight.data = torch.tensor([[2.50, 2.50]])       # 두 번째 레이어 가중치 (두 값의 가중합)
l2.bias.data   = torch.tensor([-2.50])              # 두 번째 레이어 편향

# 시각화 코드
fig, ax = plt.subplots(1, 3, figsize=(9, 3))

# 첫 번째 레이어: 선형 변환 결과 시각화
ax[0].plot(x, l1(x).data.numpy(), '--', color='C1')
ax[0].set_title('$l_1(x)$')  # 선형 변환 (Wx + b)

# 두 번째 레이어: 시그모이드 활성화 결과 시각화
ax[1].plot(x, a1(l1(x)).data.numpy(), '--', color='C1')
ax[1].set_title('$(a_1 \circ l_1)(x)$')  # 활성화 함수 적용 결과

# 전체 네트워크 출력 시각화
ax[2].plot(x, l2(a1(l1(x))).data, '--', color='C1')
ax[2].set_title('$(l_2 \circ a_1 \circ l_1)(x)$')  # 최종 출력
ax[2].set_ylim(-0.1, 2.6)  # y축 범위 설정

#
# Out:
# (-0.1, 2.6)

# %% [markdown]
# `-` 직관3: `은닉층의노드수=4`로 하고 적당한 가중치를 조정하면 $(l_2\circ a_1 \circ l_1)(x)$의 결과로 주황색선 + 파란색선도 가능할 것 같다. $\to$ 실제로 가능함

# %%
l1 = torch.nn.Linear(in_features=1,out_features=4)
a1 = torch.nn.Sigmoid()
l2 = torch.nn.Linear(in_features=4,out_features=1)

# %%
l1.weight.data = torch.tensor([[-5.00],[5.00],[-5.00],[5.00]])
l1.bias.data = torch.tensor([0.00, 20.00, 20.00, 0])
l2.weight.data = torch.tensor([[1.00,  1.00, 2.50,  2.50]])
l2.bias.data = torch.tensor([-1.0-2.5])

# %%
plt.plot(l2(a1(l1(x))).data,'--')
plt.title(r"$(l_2 \circ a_1 \circ l_1)(x)$")
# Out:
# Text(0.5, 1.0, '$(l_2 \\circ a_1 \\circ l_1)(x)$')

# %% [markdown]
# > 이러한 함수는 계단모양이며, 0을 제외한 서로다른 계단의 높이는 2개가 된다. 이를 간단히 "2단계-계단함수"라고 칭하자.

# %% [markdown]
# `-` 정리1: 2개의 시그모이드를 우연히 잘 결합하면 아래와 같은 "1단계-계단함수" 함수 $h$를 만들 수 있다.

# %%
## 수업 시간에 추가로
sig = torch.nn.Sigmoid()

# %%
## 수업 시간에 추가로
plt.plot(x,sig(200*(x-0.5)))

# %%
## 수업 시간에 추가로
def h(x):
  sig = torch.nn.Sigmoid()
  v1 = - sig(200*(x-0.5))
  v2 = sig(200*(x+0.5))
  return v1 + v2

# %%
## 수업 시간에 추가로
plt.plot(x,h(x))
plt.title("$h(x)$")
# Out:
# Text(0.5, 1.0, '$h(x)$')

# %%
h = lambda x: torch.sigmoid(200*(x+0.5))+torch.sigmoid(-200*(x-0.5))-1.0

# %%
plt.plot(x,h(x))
plt.title("$h(x)$")
# Out:
# Text(0.5, 1.0, '$h(x)$')

# %% [markdown]
# `-` 정리2: 위와 같은 함수 $h$를 활성화함수로 하고 $m$개의 노드를 가지는 은닉층을 생각해보자. 이러한 은닉층을 사용한다면 "m단계-계단함수"와 같은 형태의 네트워크는 아래와 같이 $m$개의 은닉노드를 써서 항상 표현할 수 있다.

# %% [markdown]
# $$\underset{(n,1)}{\bf X} \overset{l_1}{\to} \underset{(n,m)}{\boldsymbol u^{(1)}} \overset{h}{\to} \underset{(n,m)}{\boldsymbol v^{(1)}} \overset{l_2}{\to} \underset{(n,1)}{\hat{\boldsymbol y}}$$

# %% [markdown]
# 그리고 위의 네트워크와 동일한 효과를 주는 아래의 네트워크가 항상 존재함.

# %% [markdown]
# $$\underset{(n,1)}{\bf X} \overset{l_1}{\to} \underset{(n,2m)}{\boldsymbol u^{(1)}} \overset{sig}{\to} \underset{(n,2m)}{\boldsymbol v^{(1)}} \overset{l_2}{\to} \underset{(n,1)}{\hat{\boldsymbol y}}$$

# %%
## 수업 시간에 추가로
# h 자체를 두개의 시그모이드로 만든거니까 당연한 말이다.

# %% [markdown]
# `-` 직관4: 그런데 어떠한 함수형태라도 구불구불한 "m단계-계단함수"로 다 근사할 수 있지 않나?

# %% [markdown]
# ## C. $h$의 위력

# %% [markdown]
# `-` $h(x)$를 생성하는 클래스를 만들어보자.

# %%
## 수업 시간에 추가로 - 클래스 탬플릿 --> 이건 그냥 외워야함.
class H(torch.nn.Module):
  def __init__(self):
    super().__init__()
  def forward(self, u):
    out = h(x)
    return out

# %%
## 수업 시간에 추가로

class H(torch.nn.Module):
  def __init__(self):
    super().__init__()
  def forward(self, x):
    def h(x):
      sig = torch.nn.Sigmoid()
      v1 = - sig(200*(x-0.5))
      v2 = sig(200*(x+0.5))
      return v1 + v2
    out = h(x)

    return out

# %%
class MyActivation(torch.nn.Module): ## 사용자정의 활성화함수를 선언하는 방법
    def __init__(self):
        super().__init__()
    def forward(self, u):
        h = lambda x: torch.sigmoid(200*(x+0.5))+torch.sigmoid(-200*(x-0.5))-1.0
        v = h(u)
        return v # activation 의 출력

# %%
a1 = MyActivation()
# a1 = torch.nn.Sigmoid(), a1 = torch.nn.ReLU() 대신에 a1 = MyActivation()

# %% [markdown]
# `-` 아래와 같이 하나의 은닉층을 가지고 있더라도 많은 노드수만 보장되면 매우 충분한 표현력을 가짐

# %% [markdown]
# $$\underset{(n,1)}{\bf X} \overset{l_1}{\to} \underset{(n,m)}{\boldsymbol u^{(1)}} \overset{h}{\to} \underset{(n,m)}{\boldsymbol v^{(1)}} \overset{l_2}{\to} \underset{(n,1)}{\hat{\boldsymbol y}}$$

# %% [markdown]
# `-` $h$의 위력을 체감해보자.

# %% [markdown]
# `# 예제1` -- 스펙의 역설

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guebin/DL2025/main/posts/ironyofspec.csv")
x = torch.tensor(df.x).float().reshape(-1,1)
y = torch.tensor(df.y).float().reshape(-1,1)
prob = torch.tensor(df.prob).float().reshape(-1,1)

# %%
torch.manual_seed(43052)
class MyActivation(torch.nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, u):
        h = lambda x: torch.sigmoid(200*(x+0.5))+torch.sigmoid(-200*(x-0.5))-1.0
        v = h(u)
        return v
#---#
net = torch.nn.Sequential(
    torch.nn.Linear(1,2048),
    MyActivation(),
    torch.nn.Linear(2048,1),
    torch.nn.Sigmoid()
)
loss_fn = torch.nn.BCELoss()
optimizr = torch.optim.Adam(net.parameters())
#---#
for epoc in range(100):
    ## 1
    yhat = net(x)
    ## 2
    loss = loss_fn(yhat,y)
    ## 3
    loss.backward()
    ## 4
    optimizr.step()
    optimizr.zero_grad()

# %%
plt.plot(x,y,'o',alpha=0.2, label="observed data (with error)")
plt.plot(x,prob,'--', label="prob (true, unknown)")
plt.plot(x,net(x).data,'--',label="prob (estimated)")
plt.legend()

# %% [markdown]
# `#`

# %% [markdown]
# `# 예제2` -- 수능곡선

# %%
torch.manual_seed(43052)
x = torch.linspace(0,2,2000).reshape(-1,1)
eps = torch.randn(2000).reshape(-1,1)*0.05
fx = torch.exp(-1*x)* torch.abs(torch.cos(3*x))*(torch.sin(3*x))
y = fx + eps

# %%
torch.manual_seed(43052)
class MyActivation(torch.nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, u):
        h = lambda x: torch.sigmoid(200*(x+0.5))+torch.sigmoid(-200*(x-0.5))-1.0
        v = h(u)
        return v
#---#
net = torch.nn.Sequential(
    torch.nn.Linear(1,2048),
    MyActivation(),
    torch.nn.Linear(2048,1),
)
loss_fn = torch.nn.MSELoss()
optimizr = torch.optim.Adam(net.parameters())
#---#
for epoc in range(100):
    ## 1
    yhat = net(x)
    ## 2
    loss = loss_fn(yhat,y)
    ## 3
    loss.backward()
    ## 4
    optimizr.step()
    optimizr.zero_grad()

# %%
plt.plot(x,y,alpha=0.2,label="observed data (with error)")
plt.plot(x,fx,'--',label="underlying (true, unknown)")
plt.plot(x,net(x).data,'--',label="underlying (estimated)")
plt.legend()

# %% [markdown]
# `#`

# %% [markdown]
# ## D. 의문점

# %% [markdown]
# `-` 이 수업을 잘 이해한 사람: 그냥 활성화함수를 $h$로 쓰면 끝 아니야? 뭐하러 relu 를 쓰는거지?

# %% [markdown]
# `-` 딥러닝을 좀 공부해본사람1: 왜 딥러닝이 2010년이 지나서야 떳지? 1989년에 세상의 모든 문제가 풀려야 하는것 아닌가?

# %% [markdown]
# `-` 딥러닝을 좀 공부해본사람2: 하나의 은닉층을 가진 네크워크는 잘 안쓰지 않나? 은닉층이 깊을수록 좋다고 들었는데?

# %% [markdown]
# `-` 약간의 의구심이 있지만 아무튼 우리는 아래의 무기를 가진 꼴이 되었다.
#
# ::: {.callout-tip}
# ### 우리의 무기
#
# 하나의 은닉층을 가지는 아래와 같은 꼴의 네트워크로,
# ```Python
# net = torch.nn.Sequential(
#     torch.nn.Linear(p,???),
#     torch.nn.Sigmoid(),
#     torch.nn.Linear(???,q)
# )
# ```
#
# $f: {\bf X}_{n \times p} \to {\bf y}_{n\times q}$ 인 모든 보렐 가측 함수 $f$ 을 원하는 정확도로 "근사"시킬 수 있다.
# :::

# %% [markdown]
# # 5. MNIST 해결

# %% [markdown]
# ## A. 예비학습 -- ``plt.imshow()`

# %% [markdown]
# `-` `plt.imshow(...)` 에서 `...`이 shape이 (??,??)이면 흑백이미지를 출력

# %%
plt.imshow([[0,255],[0,255]],cmap='gray')

# %% [markdown]
# `-` `plt.imshow(...)` 에서 `...`의 shape이 (??,??,3)이면 칼라이미지를 출력

# %%
r = [[0,255],[0,255]]
g = [[255,0],[0,0]]
b = [[0,0],[255,0]]
plt.imshow(np.stack([r,g,b],axis=2))

# %% [markdown]
# `-` `plt.imshow(...)` 에서 `...`의 자료형이 int인지 float인지에 따라서 인식이 다름

# %%
r = [[0,1],[0,1]]
g = [[1,0],[0,0]]
b = [[0,0],[1,0]]
plt.imshow(np.stack([r,g,b],axis=2))

# %%
r = [[0,1.0],[0,1.0]]
g = [[1.0,0],[0,0]]
b = [[0,0],[1.0,0]]
plt.imshow(np.stack([r,g,b],axis=2))

# %% [markdown]
# ## B. 데이터

# %% [markdown]
# `-` 데이터 정리코드

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True)
to_tensor = torchvision.transforms.ToTensor()
X3 = torch.stack([to_tensor(Xi) for Xi, yi in train_dataset if yi==3])
X7 = torch.stack([to_tensor(Xi) for Xi, yi in train_dataset if yi==7])
X = torch.concat([X3,X7],axis=0)
y = torch.tensor([0.0]*len(X3) + [1.0]*len(X7))
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 22.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 610kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.68MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.90MB/s]

# %%
plt.imshow(X[0].reshape(28,28),cmap='gray')

# %%
plt.imshow(X[-2].reshape(28,28),cmap='gray')

# %%
X.shape, y.shape
# Out:
# (torch.Size([12396, 1, 28, 28]), torch.Size([12396]))

# %%
plt.plot(y)

# %%
plt.plot(y,'o')

# %% [markdown]
# - "y=0.0" 은 숫자3을 의미함, "y=1.0" 은 숫자7을 의미함
# - 숫자3은 6131개, 숫자7은 6265개 있음

# %% [markdown]
# `-` 우리는 ${\bf X}: (n,1,28,28)$ 에서 ${\bf y}: (n,1)$으로 가는 맵핑을 배우고 싶음. $\to$ 이런건 배운적이 없는데?.. $\to$ 그렇다면 ${\bf X}:(n,784) \to {\bf y}:(n,1)$ 으로 가는 맵핑을 학습하자.

# %%
X = torch.stack([xi.reshape(-1) for xi in X])
y = y.reshape(-1,1)

# %%
X.shape
# Out:
# torch.Size([12396, 784])

# %%
X[0]
# Out:
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1490, 0.1686,
#         0.4118, 1.0000, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.6824, 0.0235,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1686, 0.5451, 0.8784,
#         0.8863, 0.9882, 0.9922, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882,
#         0.6196, 0.0549, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6980, 0.9882,
#         0.9882, 0.9882, 0.9882, 0.9922, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882,
#         0.9882, 0.9882, 0.2314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4275,
#         0.9882, 0.9882, 0.9020, 0.5176, 0.5216, 0.5176, 0.5176, 0.7412, 0.9882,
#         0.9882, 0.9882, 0.9882, 0.2314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0157, 0.1137, 0.1137, 0.0941, 0.0000, 0.0000, 0.0000, 0.0000, 0.0549,
#         0.8863, 0.9882, 0.9882, 0.6745, 0.0275, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.3333, 0.9529, 0.9882, 0.9882, 0.5647, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.3451, 0.7412, 0.9882, 0.9882, 0.9882, 0.0549, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3569,
#         0.8314, 0.9686, 0.9882, 0.9882, 0.9882, 0.8000, 0.0353, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.1255, 0.4902, 0.7569, 0.7569, 0.7569,
#         0.9922, 0.9882, 0.9882, 0.9882, 0.9333, 0.4000, 0.1098, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.8706, 0.9882, 0.9882, 0.9882,
#         0.9882, 0.9922, 0.9882, 0.9882, 0.9882, 0.6941, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.8745, 0.9922, 0.9922,
#         0.9922, 0.9922, 1.0000, 0.9922, 0.9922, 0.9922, 0.9922, 0.2902, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1216, 0.4824,
#         0.2039, 0.1725, 0.1725, 0.1725, 0.1725, 0.5608, 0.9882, 0.9882, 0.2902,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0588, 0.9882, 0.9882,
#         0.2902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3373, 0.9882,
#         0.9882, 0.2902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0196, 0.2941,
#         0.0353, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3843, 0.9490,
#         0.9882, 0.9882, 0.2902, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2392, 0.7176,
#         0.9882, 0.1137, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.3608, 0.9373,
#         0.9882, 0.9882, 0.9529, 0.2549, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8157,
#         0.9882, 0.9882, 0.5765, 0.5255, 0.5255, 0.5255, 0.5255, 0.7961, 0.9922,
#         0.9882, 0.9882, 0.7373, 0.3255, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.8157, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882,
#         0.9922, 0.9020, 0.6000, 0.0314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.1922, 0.6157, 0.9882, 0.9882, 0.9882, 0.9882, 0.9882, 0.8510,
#         0.8118, 0.5725, 0.1765, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0275, 0.4039, 0.9216, 0.9882, 0.6745, 0.4039,
#         0.0941, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000])

# %%
[img.reshape(-1) for img in x]
# Out:
# [tensor([0.]),
#  tensor([0.0010]),
#  tensor([0.0020]),
#  tensor([0.0030]),
#  tensor([0.0040]),
#  tensor([0.0050]),
#  tensor([0.0060]),
#  tensor([0.0070]),
#  tensor([0.0080]),
#  tensor([0.0090]),
#  tensor([0.0100]),
#  tensor([0.0110]),
#  tensor([0.0120]),
#  tensor([0.0130]),
#  tensor([0.0140]),
#  tensor([0.0150]),
#  tensor([0.0160]),
#  tensor([0.0170]),
#  tensor([0.0180]),
#  tensor([0.0190]),
#  tensor([0.0200]),
#  tensor([0.0210]),
#  tensor([0.0220]),
#  tensor([0.0230]),
#  tensor([0.0240]),
#  tensor([0.0250]),
#  tensor([0.0260]),
#  tensor([0.0270]),
#  tensor([0.0280]),
#  tensor([0.0290]),
#  tensor([0.0300]),
#  tensor([0.0310]),
#  tensor([0.0320]),
#  tensor([0.0330]),
#  tensor([0.0340]),
#  tensor([0.0350]),
#  tensor([0.0360]),
#  tensor([0.0370]),
#  tensor([0.0380]),
#  tensor([0.0390]),
#  tensor([0.0400]),
#  tensor([0.0410]),
#  tensor([0.0420]),
#  tensor([0.0430]),
#  tensor([0.0440]),
#  tensor([0.0450]),
#  tensor([0.0460]),
#  tensor([0.0470]),
#  tensor([0.0480]),
#  tensor([0.0490]),
#  tensor([0.0500]),
#  tensor([0.0510]),
#  tensor([0.0520]),
#  tensor([0.0530]),
#  tensor([0.0540]),
#  tensor([0.0550]),
#  tensor([0.0560]),
#  tensor([0.0570]),
#  tensor([0.0580]),
#  tensor([0.0590]),
#  tensor([0.0600]),
#  tensor([0.0610]),
#  tensor([0.0620]),
#  tensor([0.0630]),
#  tensor([0.0640]),
#  tensor([0.0650]),
#  tensor([0.0660]),
#  tensor([0.0670]),
#  tensor([0.0680]),
#  tensor([0.0690]),
#  tensor([0.0700]),
#  tensor([0.0710]),
#  tensor([0.0720]),
#  tensor([0.0730]),
#  tensor([0.0740]),
#  tensor([0.0750]),
#  tensor([0.0760]),
#  tensor([0.0770]),
#  tensor([0.0780]),
#  tensor([0.0790]),
#  tensor([0.0800]),
#  tensor([0.0810]),
#  tensor([0.0820]),
#  tensor([0.0830]),
#  tensor([0.0840]),
#  tensor([0.0850]),
#  tensor([0.0860]),
#  tensor([0.0870]),
#  tensor([0.0880]),
#  tensor([0.0890]),
#  tensor([0.0900]),
#  tensor([0.0910]),
#  tensor([0.0920]),
#  tensor([0.0930]),
#  tensor([0.0940]),
#  tensor([0.0950]),
#  tensor([0.0960]),
#  tensor([0.0970]),
#  tensor([0.0980]),
#  tensor([0.0990]),
#  tensor([0.1001]),
#  tensor([0.1011]),
#  tensor([0.1021]),
#  tensor([0.1031]),
#  tensor([0.1041]),
#  tensor([0.1051]),
#  tensor([0.1061]),
#  tensor([0.1071]),
#  tensor([0.1081]),
#  tensor([0.1091]),
#  tensor([0.1101]),
#  tensor([0.1111]),
#  tensor([0.1121]),
#  tensor([0.1131]),
#  tensor([0.1141]),
#  tensor([0.1151]),
#  tensor([0.1161]),
#  tensor([0.1171]),
#  tensor([0.1181]),
#  tensor([0.1191]),
#  tensor([0.1201]),
#  tensor([0.1211]),
#  tensor([0.1221]),
#  tensor([0.1231]),
#  tensor([0.1241]),
#  tensor([0.1251]),
#  tensor([0.1261]),
#  tensor([0.1271]),
#  tensor([0.1281]),
#  tensor([0.1291]),
#  tensor([0.1301]),
#  tensor([0.1311]),
#  tensor([0.1321]),
#  tensor([0.1331]),
#  tensor([0.1341]),
#  tensor([0.1351]),
#  tensor([0.1361]),
#  tensor([0.1371]),
#  tensor([0.1381]),
#  tensor([0.1391]),
#  tensor([0.1401]),
#  tensor([0.1411]),
#  tensor([0.1421]),
#  tensor([0.1431]),
#  tensor([0.1441]),
#  tensor([0.1451]),
#  tensor([0.1461]),
#  tensor([0.1471]),
#  tensor([0.1481]),
#  tensor([0.1491]),
#  tensor([0.1501]),
#  tensor([0.1511]),
#  tensor([0.1521]),
#  tensor([0.1531]),
#  tensor([0.1541]),
#  tensor([0.1551]),
#  tensor([0.1561]),
#  tensor([0.1571]),
#  tensor([0.1581]),
#  tensor([0.1591]),
#  tensor([0.1601]),
#  tensor([0.1611]),
#  tensor([0.1621]),
#  tensor([0.1631]),
#  tensor([0.1641]),
#  tensor([0.1651]),
#  tensor([0.1661]),
#  tensor([0.1671]),
#  tensor([0.1681]),
#  tensor([0.1691]),
#  tensor([0.1701]),
#  tensor([0.1711]),
#  tensor([0.1721]),
#  tensor([0.1731]),
#  tensor([0.1741]),
#  tensor([0.1751]),
#  tensor([0.1761]),
#  tensor([0.1771]),
#  tensor([0.1781]),
#  tensor([0.1791]),
#  tensor([0.1801]),
#  tensor([0.1811]),
#  tensor([0.1821]),
#  tensor([0.1831]),
#  tensor([0.1841]),
#  tensor([0.1851]),
#  tensor([0.1861]),
#  tensor([0.1871]),
#  tensor([0.1881]),
#  tensor([0.1891]),
#  tensor([0.1901]),
#  tensor([0.1911]),
#  tensor([0.1921]),
#  tensor([0.1931]),
#  tensor([0.1941]),
#  tensor([0.1951]),
#  tensor([0.1961]),
#  tensor([0.1971]),
#  tensor([0.1981]),
#  tensor([0.1991]),
#  tensor([0.2001]),
#  tensor([0.2011]),
#  tensor([0.2021]),
#  tensor([0.2031]),
#  tensor([0.2041]),
#  tensor([0.2051]),
#  tensor([0.2061]),
#  tensor([0.2071]),
#  tensor([0.2081]),
#  tensor([0.2091]),
#  tensor([0.2101]),
#  tensor([0.2111]),
#  tensor([0.2121]),
#  tensor([0.2131]),
#  tensor([0.2141]),
#  tensor([0.2151]),
#  tensor([0.2161]),
#  tensor([0.2171]),
#  tensor([0.2181]),
#  tensor([0.2191]),
#  tensor([0.2201]),
#  tensor([0.2211]),
#  tensor([0.2221]),
#  tensor([0.2231]),
#  tensor([0.2241]),
#  tensor([0.2251]),
#  tensor([0.2261]),
#  tensor([0.2271]),
#  tensor([0.2281]),
#  tensor([0.2291]),
#  tensor([0.2301]),
#  tensor([0.2311]),
#  tensor([0.2321]),
#  tensor([0.2331]),
#  tensor([0.2341]),
#  tensor([0.2351]),
#  tensor([0.2361]),
#  tensor([0.2371]),
#  tensor([0.2381]),
#  tensor([0.2391]),
#  tensor([0.2401]),
#  tensor([0.2411]),
#  tensor([0.2421]),
#  tensor([0.2431]),
#  tensor([0.2441]),
#  tensor([0.2451]),
#  tensor([0.2461]),
#  tensor([0.2471]),
#  tensor([0.2481]),
#  tensor([0.2491]),
#  tensor([0.2501]),
#  tensor([0.2511]),
#  tensor([0.2521]),
#  tensor([0.2531]),
#  tensor([0.2541]),
#  tensor([0.2551]),
#  tensor([0.2561]),
#  tensor([0.2571]),
#  tensor([0.2581]),
#  tensor([0.2591]),
#  tensor([0.2601]),
#  tensor([0.2611]),
#  tensor([0.2621]),
#  tensor([0.2631]),
#  tensor([0.2641]),
#  tensor([0.2651]),
#  tensor([0.2661]),
#  tensor([0.2671]),
#  tensor([0.2681]),
#  tensor([0.2691]),
#  tensor([0.2701]),
#  tensor([0.2711]),
#  tensor([0.2721]),
#  tensor([0.2731]),
#  tensor([0.2741]),
#  tensor([0.2751]),
#  tensor([0.2761]),
#  tensor([0.2771]),
#  tensor([0.2781]),
#  tensor([0.2791]),
#  tensor([0.2801]),
#  tensor([0.2811]),
#  tensor([0.2821]),
#  tensor([0.2831]),
#  tensor([0.2841]),
#  tensor([0.2851]),
#  tensor([0.2861]),
#  tensor([0.2871]),
#  tensor([0.2881]),
#  tensor([0.2891]),
#  tensor([0.2901]),
#  tensor([0.2911]),
#  tensor([0.2921]),
#  tensor([0.2931]),
#  tensor([0.2941]),
#  tensor([0.2951]),
#  tensor([0.2961]),
#  tensor([0.2971]),
#  tensor([0.2981]),
#  tensor([0.2991]),
#  tensor([0.3002]),
#  tensor([0.3012]),
#  tensor([0.3022]),
#  tensor([0.3032]),
#  tensor([0.3042]),
#  tensor([0.3052]),
#  tensor([0.3062]),
#  tensor([0.3072]),
#  tensor([0.3082]),
#  tensor([0.3092]),
#  tensor([0.3102]),
#  tensor([0.3112]),
#  tensor([0.3122]),
#  tensor([0.3132]),
#  tensor([0.3142]),
#  tensor([0.3152]),
#  tensor([0.3162]),
#  tensor([0.3172]),
#  tensor([0.3182]),
#  tensor([0.3192]),
#  tensor([0.3202]),
#  tensor([0.3212]),
#  tensor([0.3222]),
#  tensor([0.3232]),
#  tensor([0.3242]),
#  tensor([0.3252]),
#  tensor([0.3262]),
#  tensor([0.3272]),
#  tensor([0.3282]),
#  tensor([0.3292]),
#  tensor([0.3302]),
#  tensor([0.3312]),
#  tensor([0.3322]),
#  tensor([0.3332]),
#  tensor([0.3342]),
#  tensor([0.3352]),
#  tensor([0.3362]),
#  tensor([0.3372]),
#  tensor([0.3382]),
#  tensor([0.3392]),
#  tensor([0.3402]),
#  tensor([0.3412]),
#  tensor([0.3422]),
#  tensor([0.3432]),
#  tensor([0.3442]),
#  tensor([0.3452]),
#  tensor([0.3462]),
#  tensor([0.3472]),
#  tensor([0.3482]),
#  tensor([0.3492]),
#  tensor([0.3502]),
#  tensor([0.3512]),
#  tensor([0.3522]),
#  tensor([0.3532]),
#  tensor([0.3542]),
#  tensor([0.3552]),
#  tensor([0.3562]),
#  tensor([0.3572]),
#  tensor([0.3582]),
#  tensor([0.3592]),
#  tensor([0.3602]),
#  tensor([0.3612]),
#  tensor([0.3622]),
#  tensor([0.3632]),
#  tensor([0.3642]),
#  tensor([0.3652]),
#  tensor([0.3662]),
#  tensor([0.3672]),
#  tensor([0.3682]),
#  tensor([0.3692]),
#  tensor([0.3702]),
#  tensor([0.3712]),
#  tensor([0.3722]),
#  tensor([0.3732]),
#  tensor([0.3742]),
#  tensor([0.3752]),
#  tensor([0.3762]),
#  tensor([0.3772]),
#  tensor([0.3782]),
#  tensor([0.3792]),
#  tensor([0.3802]),
#  tensor([0.3812]),
#  tensor([0.3822]),
#  tensor([0.3832]),
#  tensor([0.3842]),
#  tensor([0.3852]),
#  tensor([0.3862]),
#  tensor([0.3872]),
#  tensor([0.3882]),
#  tensor([0.3892]),
#  tensor([0.3902]),
#  tensor([0.3912]),
#  tensor([0.3922]),
#  tensor([0.3932]),
#  tensor([0.3942]),
#  tensor([0.3952]),
#  tensor([0.3962]),
#  tensor([0.3972]),
#  tensor([0.3982]),
#  tensor([0.3992]),
#  tensor([0.4002]),
#  tensor([0.4012]),
#  tensor([0.4022]),
#  tensor([0.4032]),
#  tensor([0.4042]),
#  tensor([0.4052]),
#  tensor([0.4062]),
#  tensor([0.4072]),
#  tensor([0.4082]),
#  tensor([0.4092]),
#  tensor([0.4102]),
#  tensor([0.4112]),
#  tensor([0.4122]),
#  tensor([0.4132]),
#  tensor([0.4142]),
#  tensor([0.4152]),
#  tensor([0.4162]),
#  tensor([0.4172]),
#  tensor([0.4182]),
#  tensor([0.4192]),
#  tensor([0.4202]),
#  tensor([0.4212]),
#  tensor([0.4222]),
#  tensor([0.4232]),
#  tensor([0.4242]),
#  tensor([0.4252]),
#  tensor([0.4262]),
#  tensor([0.4272]),
#  tensor([0.4282]),
#  tensor([0.4292]),
#  tensor([0.4302]),
#  tensor([0.4312]),
#  tensor([0.4322]),
#  tensor([0.4332]),
#  tensor([0.4342]),
#  tensor([0.4352]),
#  tensor([0.4362]),
#  tensor([0.4372]),
#  tensor([0.4382]),
#  tensor([0.4392]),
#  tensor([0.4402]),
#  tensor([0.4412]),
#  tensor([0.4422]),
#  tensor([0.4432]),
#  tensor([0.4442]),
#  tensor([0.4452]),
#  tensor([0.4462]),
#  tensor([0.4472]),
#  tensor([0.4482]),
#  tensor([0.4492]),
#  tensor([0.4502]),
#  tensor([0.4512]),
#  tensor([0.4522]),
#  tensor([0.4532]),
#  tensor([0.4542]),
#  tensor([0.4552]),
#  tensor([0.4562]),
#  tensor([0.4572]),
#  tensor([0.4582]),
#  tensor([0.4592]),
#  tensor([0.4602]),
#  tensor([0.4612]),
#  tensor([0.4622]),
#  tensor([0.4632]),
#  tensor([0.4642]),
#  tensor([0.4652]),
#  tensor([0.4662]),
#  tensor([0.4672]),
#  tensor([0.4682]),
#  tensor([0.4692]),
#  tensor([0.4702]),
#  tensor([0.4712]),
#  tensor([0.4722]),
#  tensor([0.4732]),
#  tensor([0.4742]),
#  tensor([0.4752]),
#  tensor([0.4762]),
#  tensor([0.4772]),
#  tensor([0.4782]),
#  tensor([0.4792]),
#  tensor([0.4802]),
#  tensor([0.4812]),
#  tensor([0.4822]),
#  tensor([0.4832]),
#  tensor([0.4842]),
#  tensor([0.4852]),
#  tensor([0.4862]),
#  tensor([0.4872]),
#  tensor([0.4882]),
#  tensor([0.4892]),
#  tensor([0.4902]),
#  tensor([0.4912]),
#  tensor([0.4922]),
#  tensor([0.4932]),
#  tensor([0.4942]),
#  tensor([0.4952]),
#  tensor([0.4962]),
#  tensor([0.4972]),
#  tensor([0.4982]),
#  tensor([0.4992]),
#  tensor([0.5003]),
#  tensor([0.5013]),
#  tensor([0.5023]),
#  tensor([0.5033]),
#  tensor([0.5043]),
#  tensor([0.5053]),
#  tensor([0.5063]),
#  tensor([0.5073]),
#  tensor([0.5083]),
#  tensor([0.5093]),
#  tensor([0.5103]),
#  tensor([0.5113]),
#  tensor([0.5123]),
#  tensor([0.5133]),
#  tensor([0.5143]),
#  tensor([0.5153]),
#  tensor([0.5163]),
#  tensor([0.5173]),
#  tensor([0.5183]),
#  tensor([0.5193]),
#  tensor([0.5203]),
#  tensor([0.5213]),
#  tensor([0.5223]),
#  tensor([0.5233]),
#  tensor([0.5243]),
#  tensor([0.5253]),
#  tensor([0.5263]),
#  tensor([0.5273]),
#  tensor([0.5283]),
#  tensor([0.5293]),
#  tensor([0.5303]),
#  tensor([0.5313]),
#  tensor([0.5323]),
#  tensor([0.5333]),
#  tensor([0.5343]),
#  tensor([0.5353]),
#  tensor([0.5363]),
#  tensor([0.5373]),
#  tensor([0.5383]),
#  tensor([0.5393]),
#  tensor([0.5403]),
#  tensor([0.5413]),
#  tensor([0.5423]),
#  tensor([0.5433]),
#  tensor([0.5443]),
#  tensor([0.5453]),
#  tensor([0.5463]),
#  tensor([0.5473]),
#  tensor([0.5483]),
#  tensor([0.5493]),
#  tensor([0.5503]),
#  tensor([0.5513]),
#  tensor([0.5523]),
#  tensor([0.5533]),
#  tensor([0.5543]),
#  tensor([0.5553]),
#  tensor([0.5563]),
#  tensor([0.5573]),
#  tensor([0.5583]),
#  tensor([0.5593]),
#  tensor([0.5603]),
#  tensor([0.5613]),
#  tensor([0.5623]),
#  tensor([0.5633]),
#  tensor([0.5643]),
#  tensor([0.5653]),
#  tensor([0.5663]),
#  tensor([0.5673]),
#  tensor([0.5683]),
#  tensor([0.5693]),
#  tensor([0.5703]),
#  tensor([0.5713]),
#  tensor([0.5723]),
#  tensor([0.5733]),
#  tensor([0.5743]),
#  tensor([0.5753]),
#  tensor([0.5763]),
#  tensor([0.5773]),
#  tensor([0.5783]),
#  tensor([0.5793]),
#  tensor([0.5803]),
#  tensor([0.5813]),
#  tensor([0.5823]),
#  tensor([0.5833]),
#  tensor([0.5843]),
#  tensor([0.5853]),
#  tensor([0.5863]),
#  tensor([0.5873]),
#  tensor([0.5883]),
#  tensor([0.5893]),
#  tensor([0.5903]),
#  tensor([0.5913]),
#  tensor([0.5923]),
#  tensor([0.5933]),
#  tensor([0.5943]),
#  tensor([0.5953]),
#  tensor([0.5963]),
#  tensor([0.5973]),
#  tensor([0.5983]),
#  tensor([0.5993]),
#  tensor([0.6003]),
#  tensor([0.6013]),
#  tensor([0.6023]),
#  tensor([0.6033]),
#  tensor([0.6043]),
#  tensor([0.6053]),
#  tensor([0.6063]),
#  tensor([0.6073]),
#  tensor([0.6083]),
#  tensor([0.6093]),
#  tensor([0.6103]),
#  tensor([0.6113]),
#  tensor([0.6123]),
#  tensor([0.6133]),
#  tensor([0.6143]),
#  tensor([0.6153]),
#  tensor([0.6163]),
#  tensor([0.6173]),
#  tensor([0.6183]),
#  tensor([0.6193]),
#  tensor([0.6203]),
#  tensor([0.6213]),
#  tensor([0.6223]),
#  tensor([0.6233]),
#  tensor([0.6243]),
#  tensor([0.6253]),
#  tensor([0.6263]),
#  tensor([0.6273]),
#  tensor([0.6283]),
#  tensor([0.6293]),
#  tensor([0.6303]),
#  tensor([0.6313]),
#  tensor([0.6323]),
#  tensor([0.6333]),
#  tensor([0.6343]),
#  tensor([0.6353]),
#  tensor([0.6363]),
#  tensor([0.6373]),
#  tensor([0.6383]),
#  tensor([0.6393]),
#  tensor([0.6403]),
#  tensor([0.6413]),
#  tensor([0.6423]),
#  tensor([0.6433]),
#  tensor([0.6443]),
#  tensor([0.6453]),
#  tensor([0.6463]),
#  tensor([0.6473]),
#  tensor([0.6483]),
#  tensor([0.6493]),
#  tensor([0.6503]),
#  tensor([0.6513]),
#  tensor([0.6523]),
#  tensor([0.6533]),
#  tensor([0.6543]),
#  tensor([0.6553]),
#  tensor([0.6563]),
#  tensor([0.6573]),
#  tensor([0.6583]),
#  tensor([0.6593]),
#  tensor([0.6603]),
#  tensor([0.6613]),
#  tensor([0.6623]),
#  tensor([0.6633]),
#  tensor([0.6643]),
#  tensor([0.6653]),
#  tensor([0.6663]),
#  tensor([0.6673]),
#  tensor([0.6683]),
#  tensor([0.6693]),
#  tensor([0.6703]),
#  tensor([0.6713]),
#  tensor([0.6723]),
#  tensor([0.6733]),
#  tensor([0.6743]),
#  tensor([0.6753]),
#  tensor([0.6763]),
#  tensor([0.6773]),
#  tensor([0.6783]),
#  tensor([0.6793]),
#  tensor([0.6803]),
#  tensor([0.6813]),
#  tensor([0.6823]),
#  tensor([0.6833]),
#  tensor([0.6843]),
#  tensor([0.6853]),
#  tensor([0.6863]),
#  tensor([0.6873]),
#  tensor([0.6883]),
#  tensor([0.6893]),
#  tensor([0.6903]),
#  tensor([0.6913]),
#  tensor([0.6923]),
#  tensor([0.6933]),
#  tensor([0.6943]),
#  tensor([0.6953]),
#  tensor([0.6963]),
#  tensor([0.6973]),
#  tensor([0.6983]),
#  tensor([0.6993]),
#  tensor([0.7004]),
#  tensor([0.7014]),
#  tensor([0.7024]),
#  tensor([0.7034]),
#  tensor([0.7044]),
#  tensor([0.7054]),
#  tensor([0.7064]),
#  tensor([0.7074]),
#  tensor([0.7084]),
#  tensor([0.7094]),
#  tensor([0.7104]),
#  tensor([0.7114]),
#  tensor([0.7124]),
#  tensor([0.7134]),
#  tensor([0.7144]),
#  tensor([0.7154]),
#  tensor([0.7164]),
#  tensor([0.7174]),
#  tensor([0.7184]),
#  tensor([0.7194]),
#  tensor([0.7204]),
#  tensor([0.7214]),
#  tensor([0.7224]),
#  tensor([0.7234]),
#  tensor([0.7244]),
#  tensor([0.7254]),
#  tensor([0.7264]),
#  tensor([0.7274]),
#  tensor([0.7284]),
#  tensor([0.7294]),
#  tensor([0.7304]),
#  tensor([0.7314]),
#  tensor([0.7324]),
#  tensor([0.7334]),
#  tensor([0.7344]),
#  tensor([0.7354]),
#  tensor([0.7364]),
#  tensor([0.7374]),
#  tensor([0.7384]),
#  tensor([0.7394]),
#  tensor([0.7404]),
#  tensor([0.7414]),
#  tensor([0.7424]),
#  tensor([0.7434]),
#  tensor([0.7444]),
#  tensor([0.7454]),
#  tensor([0.7464]),
#  tensor([0.7474]),
#  tensor([0.7484]),
#  tensor([0.7494]),
#  tensor([0.7504]),
#  tensor([0.7514]),
#  tensor([0.7524]),
#  tensor([0.7534]),
#  tensor([0.7544]),
#  tensor([0.7554]),
#  tensor([0.7564]),
#  tensor([0.7574]),
#  tensor([0.7584]),
#  tensor([0.7594]),
#  tensor([0.7604]),
#  tensor([0.7614]),
#  tensor([0.7624]),
#  tensor([0.7634]),
#  tensor([0.7644]),
#  tensor([0.7654]),
#  tensor([0.7664]),
#  tensor([0.7674]),
#  tensor([0.7684]),
#  tensor([0.7694]),
#  tensor([0.7704]),
#  tensor([0.7714]),
#  tensor([0.7724]),
#  tensor([0.7734]),
#  tensor([0.7744]),
#  tensor([0.7754]),
#  tensor([0.7764]),
#  tensor([0.7774]),
#  tensor([0.7784]),
#  tensor([0.7794]),
#  tensor([0.7804]),
#  tensor([0.7814]),
#  tensor([0.7824]),
#  tensor([0.7834]),
#  tensor([0.7844]),
#  tensor([0.7854]),
#  tensor([0.7864]),
#  tensor([0.7874]),
#  tensor([0.7884]),
#  tensor([0.7894]),
#  tensor([0.7904]),
#  tensor([0.7914]),
#  tensor([0.7924]),
#  tensor([0.7934]),
#  tensor([0.7944]),
#  tensor([0.7954]),
#  tensor([0.7964]),
#  tensor([0.7974]),
#  tensor([0.7984]),
#  tensor([0.7994]),
#  tensor([0.8004]),
#  tensor([0.8014]),
#  tensor([0.8024]),
#  tensor([0.8034]),
#  tensor([0.8044]),
#  tensor([0.8054]),
#  tensor([0.8064]),
#  tensor([0.8074]),
#  tensor([0.8084]),
#  tensor([0.8094]),
#  tensor([0.8104]),
#  tensor([0.8114]),
#  tensor([0.8124]),
#  tensor([0.8134]),
#  tensor([0.8144]),
#  tensor([0.8154]),
#  tensor([0.8164]),
#  tensor([0.8174]),
#  tensor([0.8184]),
#  tensor([0.8194]),
#  tensor([0.8204]),
#  tensor([0.8214]),
#  tensor([0.8224]),
#  tensor([0.8234]),
#  tensor([0.8244]),
#  tensor([0.8254]),
#  tensor([0.8264]),
#  tensor([0.8274]),
#  tensor([0.8284]),
#  tensor([0.8294]),
#  tensor([0.8304]),
#  tensor([0.8314]),
#  tensor([0.8324]),
#  tensor([0.8334]),
#  tensor([0.8344]),
#  tensor([0.8354]),
#  tensor([0.8364]),
#  tensor([0.8374]),
#  tensor([0.8384]),
#  tensor([0.8394]),
#  tensor([0.8404]),
#  tensor([0.8414]),
#  tensor([0.8424]),
#  tensor([0.8434]),
#  tensor([0.8444]),
#  tensor([0.8454]),
#  tensor([0.8464]),
#  tensor([0.8474]),
#  tensor([0.8484]),
#  tensor([0.8494]),
#  tensor([0.8504]),
#  tensor([0.8514]),
#  tensor([0.8524]),
#  tensor([0.8534]),
#  tensor([0.8544]),
#  tensor([0.8554]),
#  tensor([0.8564]),
#  tensor([0.8574]),
#  tensor([0.8584]),
#  tensor([0.8594]),
#  tensor([0.8604]),
#  tensor([0.8614]),
#  tensor([0.8624]),
#  tensor([0.8634]),
#  tensor([0.8644]),
#  tensor([0.8654]),
#  tensor([0.8664]),
#  tensor([0.8674]),
#  tensor([0.8684]),
#  tensor([0.8694]),
#  tensor([0.8704]),
#  tensor([0.8714]),
#  tensor([0.8724]),
#  tensor([0.8734]),
#  tensor([0.8744]),
#  tensor([0.8754]),
#  tensor([0.8764]),
#  tensor([0.8774]),
#  tensor([0.8784]),
#  tensor([0.8794]),
#  tensor([0.8804]),
#  tensor([0.8814]),
#  tensor([0.8824]),
#  tensor([0.8834]),
#  tensor([0.8844]),
#  tensor([0.8854]),
#  tensor([0.8864]),
#  tensor([0.8874]),
#  tensor([0.8884]),
#  tensor([0.8894]),
#  tensor([0.8904]),
#  tensor([0.8914]),
#  tensor([0.8924]),
#  tensor([0.8934]),
#  tensor([0.8944]),
#  tensor([0.8954]),
#  tensor([0.8964]),
#  tensor([0.8974]),
#  tensor([0.8984]),
#  tensor([0.8994]),
#  tensor([0.9005]),
#  tensor([0.9015]),
#  tensor([0.9025]),
#  tensor([0.9035]),
#  tensor([0.9045]),
#  tensor([0.9055]),
#  tensor([0.9065]),
#  tensor([0.9075]),
#  tensor([0.9085]),
#  tensor([0.9095]),
#  tensor([0.9105]),
#  tensor([0.9115]),
#  tensor([0.9125]),
#  tensor([0.9135]),
#  tensor([0.9145]),
#  tensor([0.9155]),
#  tensor([0.9165]),
#  tensor([0.9175]),
#  tensor([0.9185]),
#  tensor([0.9195]),
#  tensor([0.9205]),
#  tensor([0.9215]),
#  tensor([0.9225]),
#  tensor([0.9235]),
#  tensor([0.9245]),
#  tensor([0.9255]),
#  tensor([0.9265]),
#  tensor([0.9275]),
#  tensor([0.9285]),
#  tensor([0.9295]),
#  tensor([0.9305]),
#  tensor([0.9315]),
#  tensor([0.9325]),
#  tensor([0.9335]),
#  tensor([0.9345]),
#  tensor([0.9355]),
#  tensor([0.9365]),
#  tensor([0.9375]),
#  tensor([0.9385]),
#  tensor([0.9395]),
#  tensor([0.9405]),
#  tensor([0.9415]),
#  tensor([0.9425]),
#  tensor([0.9435]),
#  tensor([0.9445]),
#  tensor([0.9455]),
#  tensor([0.9465]),
#  tensor([0.9475]),
#  tensor([0.9485]),
#  tensor([0.9495]),
#  tensor([0.9505]),
#  tensor([0.9515]),
#  tensor([0.9525]),
#  tensor([0.9535]),
#  tensor([0.9545]),
#  tensor([0.9555]),
#  tensor([0.9565]),
#  tensor([0.9575]),
#  tensor([0.9585]),
#  tensor([0.9595]),
#  tensor([0.9605]),
#  tensor([0.9615]),
#  tensor([0.9625]),
#  tensor([0.9635]),
#  tensor([0.9645]),
#  tensor([0.9655]),
#  tensor([0.9665]),
#  tensor([0.9675]),
#  tensor([0.9685]),
#  tensor([0.9695]),
#  tensor([0.9705]),
#  tensor([0.9715]),
#  tensor([0.9725]),
#  tensor([0.9735]),
#  tensor([0.9745]),
#  tensor([0.9755]),
#  tensor([0.9765]),
#  tensor([0.9775]),
#  tensor([0.9785]),
#  tensor([0.9795]),
#  tensor([0.9805]),
#  tensor([0.9815]),
#  tensor([0.9825]),
#  tensor([0.9835]),
#  tensor([0.9845]),
#  tensor([0.9855]),
#  tensor([0.9865]),
#  tensor([0.9875]),
#  tensor([0.9885]),
#  tensor([0.9895]),
#  tensor([0.9905]),
#  tensor([0.9915]),
#  tensor([0.9925]),
#  tensor([0.9935]),
#  tensor([0.9945]),
#  tensor([0.9955]),
#  tensor([0.9965]),
#  tensor([0.9975]),
#  tensor([0.9985]),
#  tensor([0.9995]),
#  ...]

# %%
X = torch.concat([X3,X7],axis=0).reshape(-1,28*28).float()
X.shape, y.shape
# Out:
# (torch.Size([12396, 784]), torch.Size([12396, 1]))

# %% [markdown]
# ## C. 학습

# %%
# 시드 설정: 동일한 weight 초기화를 위해 고정
torch.manual_seed(43052)

# 모델 구성: 입력 784차원 → 은닉층 32차원 → 출력 1차원 (이진 분류)
net = torch.nn.Sequential(
    torch.nn.Linear(784, 32),  # 입력층: 784 → 32
    torch.nn.ReLU(),           # 활성화 함수: ReLU
    torch.nn.Linear(32, 1),    # 출력층: 32 → 1
    torch.nn.Sigmoid()         # 이진 확률 예측 (0~1 사이)
)

# 손실 함수: 이진 크로스 엔트로피 (Binary Cross Entropy)
loss_fn = torch.nn.BCELoss()

# 옵티마이저: Adam
optimizr = torch.optim.Adam(net.parameters())

# 학습 루프 (200 에폭 반복)
for epoc in range(2000):
    ## step1: 순전파로 예측값 계산
    yhat = net(X)

    ## step2: 손실(loss) 계산
    loss = loss_fn(yhat, y)

    ## step3: 손실 함수에 대한 gradient 계산 (역전파)
    loss.backward()

    ## step4: 옵티마이저를 통해 파라미터 업데이트
    optimizr.step()

    ## step5: gradient 초기화 (다음 역전파를 위한 준비)
    optimizr.zero_grad()

# %%
plt.plot(y,'o')
plt.plot(net(X).data,'.',alpha=0.1)
plt.legend()
# Out:
# <ipython-input-79-36bcbab9e150>:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
((yhat.data > 0.5) == y).float().mean() # train_accuracy
# Out:
# tensor(0.9894)

# %% [markdown]
# ## D. Test

# %%
XX3 = torch.stack([to_tensor(XXi) for XXi, yyi in test_dataset if yyi==3])
XX7 = torch.stack([to_tensor(XXi) for XXi, yyi in test_dataset if yyi==7])
XX = torch.concat([XX3,XX7],axis=0)
yy = torch.tensor([0.0]*len(XX3) + [1.0]*len(XX7))

# %%
XX.shape,yy.shape
# Out:
# (torch.Size([2038, 1, 28, 28]), torch.Size([2038]))

# %%
XX = torch.stack([xxi.reshape(-1) for xxi in XX])
yy = yy.reshape(-1,1)

# %%
XX.shape,yy.shape
# Out:
# (torch.Size([2038, 784]), torch.Size([2038, 1]))

# %%
plt.plot(yy,'o')
plt.plot(net(XX).data,'.',alpha=0.1)
plt.legend()
# Out:
# <ipython-input-54-8306583fbe04>:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
(yy == (net(XX)>0.5)).float().mean() # test accuracy
# Out:
# tensor(0.9843)
